# %% [markdown]
# # DATA EXPLORATION USING PANDAS

# %% [markdown]
# With the rise of short-form video platforms such as TikTok, Instagram Reels, YouTube Shorts, and Snapchat, the music industry is yet again adapting to changing consumer consumption trends.
#
# Here's the data for music used in trending videos in the second half of 2022.

# %%
import pandas as pd

# %%
sample=pd.read_csv("E:/trendsest.csv")

# %% [markdown]
# ##### To read a data in JUPYTER NOTEBOOK so we use pd.read_csv

# %%
sample
# Out:
#            Platform    Month                             Trend  \
# 0   Instagram Reels  2022/06                  DJ Wait A Minute
# 1   Instagram Reels  2022/06                        Guud Girls
# 2   Instagram Reels  2022/06              Running Up That Hill
# 3   Instagram Reels  2022/06                        Gogo Dance
# 4   Instagram Reels  2022/06                            Zedsly
# 5   Instagram Reels  2022/06  Still Don't Know My Name (Remix)
# 6   Instagram Reels  2022/06                          Manifest
# 7   Instagram Reels  2022/06                               Fur
# 8   Instagram Reels  2022/06                     BREAK MY SOUL
# 9   Instagram Reels  2022/06                     BILLIE EILISH
# 10  Instagram Reels  2022/06                          Outlands
# 11  Instagram Reels  2022/06                  The Night We Met
# 12  Instagram Reels  2022/07                           mha4bii
# 13  Instagram Reels  2022/07                        Angel Eyes
# ...

# %%
sample.head()
# Out:
#           Platform    Month                 Trend           Trend Type  \
# 0  Instagram Reels  2022/06      DJ Wait A Minute        Montage, Vlog
# 1  Instagram Reels  2022/06            Guud Girls        Montage, Vlog
# 2  Instagram Reels  2022/06  Running Up That Hill     Cosplay, Montage
# 3  Instagram Reels  2022/06            Gogo Dance  Vlog, Act Out/Dance
# 4  Instagram Reels  2022/06                Zedsly   Montage (Template)
#
#                                                Music  \
# 0                   DJ Wait A Minute - DJ Exe (2022)
# 1                Guud Girls - Breaking Beattz (2021)
# 2  Running Up That Hill (A Deal with God) - Kate ...
# 3                        Gogo Dance - El Alfa (2022)
# 4                   The Way I Are - Timbaland (2007)
#
#                              Video Style      Theme     Part of Song  \
# 0                Photo/Video Compilation  Lifestyle          Prelude
# 1                Photo/Video Compilation  Lifestyle          Prelude
# ...

# %% [markdown]
# ##### It will display only the first five data of the dataset

# %%
sample.shape
# Out:
# (49, 10)

# %% [markdown]
# ##### To display the number of Observations and Variables

# %%
sample.columns
# Out:
# Index(['Platform', 'Month', 'Trend', 'Trend Type', 'Music', 'Video Style',
#        'Theme', 'Part of Song', 'Video length in S', 'Music Genre'],
#       dtype='object')

# %% [markdown]
# ##### To show how many number of variables present in dataset

# %%
sample['Music'].value_counts()
# Out:
# DJ Wait A Minute - DJ Exe (2022)                                                   1
# One Step At A Time - Jordin Sparks (2007)                                          1
# How deep is your love? - DJ Replica (2022)                                         1
# Remix by journalbymoon (Nonstop - Drake ft. Quavo (2018))                          1
# Slipping Through my Fingers - ABBA (1981) Cover by Ethan Hodges (2022)             1
# Body Language Sickmix - Sickick (2022)                                             1
# Leave Before You Love Me - Marshmello ft. Jonas Brothers (2021)                    1
# Hold Me Closer - Elton John ft. Britney Spears (2021)                              1
# Overcome - Skott (2022)                                                            1
# Yet To Come (The Most Beautiful Moment) - BTS (2022)                               1
# BTS                                                                                1
# ...

# %% [markdown]
# ###### Value counts function is used to display how many numbers of variables and observations are present in the dataset

# %%
sample.drop_duplicates(inplace=True)

# %%
sample
# Out:
#            Platform    Month                             Trend  \
# 0   Instagram Reels  2022/06                  DJ Wait A Minute
# 1   Instagram Reels  2022/06                        Guud Girls
# 2   Instagram Reels  2022/06              Running Up That Hill
# 3   Instagram Reels  2022/06                        Gogo Dance
# 4   Instagram Reels  2022/06                            Zedsly
# 5   Instagram Reels  2022/06  Still Don't Know My Name (Remix)
# 6   Instagram Reels  2022/06                          Manifest
# 7   Instagram Reels  2022/06                               Fur
# 8   Instagram Reels  2022/06                     BREAK MY SOUL
# 9   Instagram Reels  2022/06                     BILLIE EILISH
# 10  Instagram Reels  2022/06                          Outlands
# 11  Instagram Reels  2022/06                  The Night We Met
# 12  Instagram Reels  2022/07                           mha4bii
# 13  Instagram Reels  2022/07                        Angel Eyes
# ...

# %% [markdown]
# ##### In order to identify any duplicates are present in our dataset

# %%
sample_subset=sample[['Trend','Theme']]

# %%
sample_subset
# Out:
#                                Trend                Theme
# 0                   DJ Wait A Minute            Lifestyle
# 1                         Guud Girls            Lifestyle
# 2               Running Up That Hill            Lifestyle
# 3                         Gogo Dance            Lifestyle
# 4                             Zedsly            Lifestyle
# 5   Still Don't Know My Name (Remix)            Lifestyle
# 6                           Manifest            Lifestyle
# 7                                Fur            Lifestyle
# 8                      BREAK MY SOUL            Lifestyle
# 9                      BILLIE EILISH            Lifestyle
# 10                          Outlands            Lifestyle
# 11                  The Night We Met            Lifestyle
# 12                           mha4bii            Lifestyle
# 13                        Angel Eyes            Lifestyle
# 14                           MASSIVE            Lifestyle
# ...

# %% [markdown]
# ##### To create a subset for the following dataset the sample subset is used

# %%
sample_index=sample.set_index('Platform')

# %%
sample_index
# Out:
#                    Month                             Trend  \
# Platform
# Instagram Reels  2022/06                  DJ Wait A Minute
# Instagram Reels  2022/06                        Guud Girls
# Instagram Reels  2022/06              Running Up That Hill
# Instagram Reels  2022/06                        Gogo Dance
# Instagram Reels  2022/06                            Zedsly
# Instagram Reels  2022/06  Still Don't Know My Name (Remix)
# Instagram Reels  2022/06                          Manifest
# Instagram Reels  2022/06                               Fur
# Instagram Reels  2022/06                     BREAK MY SOUL
# Instagram Reels  2022/06                     BILLIE EILISH
# Instagram Reels  2022/06                          Outlands
# Instagram Reels  2022/06                  The Night We Met
# Instagram Reels  2022/07                           mha4bii
# Instagram Reels  2022/07                        Angel Eyes
# Instagram Reels  2022/07                           MASSIVE
# ...

# %%
sample_index.reset_index()
# Out:
#            Platform    Month                             Trend  \
# 0   Instagram Reels  2022/06                  DJ Wait A Minute
# 1   Instagram Reels  2022/06                        Guud Girls
# 2   Instagram Reels  2022/06              Running Up That Hill
# 3   Instagram Reels  2022/06                        Gogo Dance
# 4   Instagram Reels  2022/06                            Zedsly
# 5   Instagram Reels  2022/06  Still Don't Know My Name (Remix)
# 6   Instagram Reels  2022/06                          Manifest
# 7   Instagram Reels  2022/06                               Fur
# 8   Instagram Reels  2022/06                     BREAK MY SOUL
# 9   Instagram Reels  2022/06                     BILLIE EILISH
# 10  Instagram Reels  2022/06                          Outlands
# 11  Instagram Reels  2022/06                  The Night We Met
# 12  Instagram Reels  2022/07                           mha4bii
# 13  Instagram Reels  2022/07                        Angel Eyes
# ...

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 48
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Platform           49 non-null     object
#  1   Month              48 non-null     object
#  2   Trend              49 non-null     object
#  3   Trend Type         49 non-null     object
#  4   Music              41 non-null     object
#  5   Video Style        49 non-null     object
#  6   Theme              49 non-null     object
#  7   Part of Song       42 non-null     object
#  8   Video length in S  47 non-null     float64
#  9   Music Genre        41 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 4.2+ KB

# %% [markdown]
# ##### Sample info is used to identify data type,column name and normal count of the dataset

# %%
sample_iloc=sample.iloc[1:15,1:6]

# %%
sample_iloc
# Out:
#       Month                             Trend                Trend Type  \
# 1   2022/06                        Guud Girls             Montage, Vlog
# 2   2022/06              Running Up That Hill          Cosplay, Montage
# 3   2022/06                        Gogo Dance       Vlog, Act Out/Dance
# 4   2022/06                            Zedsly        Montage (Template)
# 5   2022/06  Still Don't Know My Name (Remix)                   Montage
# 6   2022/06                          Manifest  Montage (Template), Vlog
# 7   2022/06                               Fur             Montage, Vlog
# 8   2022/06                     BREAK MY SOUL                   Montage
# 9   2022/06                     BILLIE EILISH       Transition, Montage
# 10  2022/06                          Outlands  Montage (Template), Vlog
# 11  2022/06                  The Night We Met             Montage, Vlog
# 12  2022/07                           mha4bii          Lip Sync (music)
# ...

# %% [markdown]
# ##### To locate desire observation and variable of the dataset sample iloc function is used

# %%
sample_loc=sample.loc[(sample.Theme=='Travel')]

# %%
sample_loc
# Out:
#            Platform    Month              Trend Trend Type  \
# 17  Instagram Reels  2022/07  A Beautiful View     Montage
#
#                                       Music              Video Style   Theme  \
# 17  Bittersweet Symphony - The Verve (1997)  Photo/Video Compilation  Travel
#
#    Part of Song  Video length in S Music Genre
# 17      Prelude                7.0       Indie

# %% [markdown]
# ##### In order to locate a specific data in a dataset

# %%
sample_agg=sample.groupby("Trend")['Video length in S'].mean()

# %%
sample_agg
# Out:
# Trend
# #BEFIRST                            15.0
# #MyBTStory                          15.0
# #PinkVenomChallenge                 10.0
# #SparklingChallenge                 14.0
# #nayeon                             13.0
# #nct127                              NaN
# 111122                              30.0
# A Beautiful View                     7.0
# Angel Eyes                          29.0
# BILLIE EILISH                       29.0
# BREAK MY SOUL                       29.0
# Before, After                        3.0
# Black Panther                       22.0
# Blood Moon                          30.0
# Body Language Sickmix               54.0
# Cinco de Mayo                       22.0
# DJ Wait A Minute                    29.0
# Election Day                        52.0
# Football                            52.0
# Friendsgiving                       22.0
# Fur                                 29.0
# Gogo Dance                          29.0
# Guud Girls                          29.0
# ...
